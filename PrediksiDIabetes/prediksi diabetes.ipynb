# %% [markdown]
# **1. Mengimport library**

# %%
import numpy as np
import pandas as pd
import pickle
import streamlit as sl
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# **2. Load dataset**

# %%
diabetes_dataset = pd.read_csv('diabetes.csv')

# %%
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
# Memisahkan data dan label
X = diabetes_dataset.drop(columns="Outcome", axis=1)
Y = diabetes_dataset["Outcome"]

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
Y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %% [markdown]
# **3. Standarisasi data**

# %%
scaler = StandardScaler()

# %%
scaler.fit(X)
# Out:
# StandardScaler()

# %%
standarized_data = scaler.transform(X)

# %%
standarized_data
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
X = standarized_data
Y = diabetes_dataset["Outcome"]

# %% [markdown]
# **4. Memisahkan data training dan data testing**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# **5. Membuat data latih dengan menggunakan algoritma SVM**

# %%
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# **6. Membuat model evaluasi untuk mengukur tingkat akurasi**

# %%
X_train_pred = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_pred, Y_train)

# %%
print("Akurasi data training:", training_data_accuracy)
# Out:
# Akurasi data training: 0.7866449511400652

# %%
X_test_pred = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_pred, Y_test)

# %%
print("Akurasi data test:", test_data_accuracy)
# Out:
# Akurasi data test: 0.7727272727272727

# %% [markdown]
# **7. Membuat model prediksi**

# %%
input_data = np.array([6, 148, 72, 35, 0, 33.6, 0.627, 50]).reshape(1, -1)
std_data = scaler.transform(input_data)
# Out:
# c:\Users\ACER\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = classifier.predict(std_data)

if (prediction[0] == 0):
    print("Pasien tidak terkena diabetes :D")
else:
    print("Pasien terkena diabetes T_T")
# Out:
# Pasien terkena diabetes T_T

# %% [markdown]
# **8. Simpan model yang sudah dilatih**

# %%
file_name = "diabetes_model.sav"
pickle.dump(classifier, open(file_name, "wb"))

# %%
# Simpan scaler
pickle.dump(scaler, open("scaler.sav", "wb"))

# Simpan model
pickle.dump(classifier, open("diabetes_model.sav", "wb"))

# %% [markdown]
# 9. Buat GUI

# %%
sl.text_input(label="Tes")
# Out:
# 2024-05-12 16:23:10.834
# ...
#   command:
#
#     streamlit run C:\Users\ACER\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# ''
